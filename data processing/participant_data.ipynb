# %% [markdown]
# # Participant Data analysis

# %% [markdown]
# ### Some participant ID may not be either CI or NH, find who is neither.
# - review how many participants in .txt ifle have a group designation in latest_demo.csv(CI vs. NH) in the data folder.
# ### Crate table, how many words were produced by the NH and CI groups (get average of participants in each group)

# %%
import pandas as pd
import numpy as np

# %%
latest_demo = pd.read_csv("Raw Data/latest_demo.csv")
latest_demo
# Out:
#        source   ID Group Gender NIH_Race NIH_Ethnicity             Income  \
# 0       billK  211    CI      M      WHT       NONHISP  $25,000 - $34,999
# 1       billK  234    CI      M      WHT       NONHISP  $15,000 - $24,999
# 2       billK  300    CI      M      WHT       NONHISP  $65,000 - $79,999
# 3       billK  308    CI      M      WHT       NONHISP  $80,000 - $94,999
# 4       billK  310    CI      F      WHT       NONHISP   $95,000 and over
# 5       billK  312    CI      F      WHT       NONHISP  $35,000 - $49,999
# 6       billK  320    CI      F      WHT          HISP  $35,000 - $49,999
# 7       billK  329    CI      M      WHT       NONHISP  $80,000 - $94,999
# 8       billK  335    CI      M      WHT       NONHISP            Unknown
# 9       billK  338    CI      F      WHT       NONHISP  $25,000 - $34,999
# 10      billK  344    CI      F      WHT       NONHISP   $95,000 and over
# 11      billK  390    CI      F      WHT       NONHISP            Unknown
# 12      billK  450    CI      F      WHT       NONHISP  $25,000 - $34,999
# 13      billK  452    CI      F    ASIAN       NONHISP            Unknown
# 14      billK  483    CI      M      WHT       NONHISP   $95,000 and over
# 15      billK  520    CI      M      WHT       NONHISP   $95,000 and over
# 16      billK  544    CI      F      WHT       NONHISP  $65,000 - $79,999
# 17      billK  556    CI      F      WHT       NONHISP  $10,000 - $14,999
# 18      billK  558    CI      M      WHT       NONHISP   $95,000 and over
# 19      billK  563    CI      M      WHT       NONHISP   $95,000 and over
# 20      billK  570    CI      M      WHT       NONHISP   $95,000 and over
# 21      billK  587    CI      M      WHT       NONHISP   $95,000 and over
# 22      billK  672    NH      F      WHT       NONHISP  $15,000 - $24,999
# 23      billK  673    NH      F      BLK       NONHISP  $15,000 - $24,999
# 24      billK  674    NH      M      WHT       NONHISP  $80,000 - $94,999
# 25      billK  681    NH      M      WHT       NONHISP  $65,000 - $79,999
# 26      billK  698    NH      M      WHT       NONHISP  $35,000 - $49,999
# 27      billK  702    NH      M      WHT       NONHISP  $50,000 - $64,999
# 28      billK  707    NH      F      WHT       NONHISP  $65,000 - $79,999
# 29      billK  711    NH      F   MULT_R       NONHISP   $95,000 and over
# 30      billK  715    NH      F   MULT_R       NONHISP  $50,000 - $64,999
# 31      billK  720    NH      M      WHT       NONHISP  $35,000 - $49,999
# 32      billK  722    NH      F      WHT       NONHISP   $95,000 and over
# 33      billK  724    NH      F      WHT       NONHISP  $25,000 - $34,999
# 34      billK  726    NH      F      WHT       NONHISP       Under $5,000
# 35      billK  730    NH      F      WHT       NONHISP   $95,000 and over
# 36      billK  744    NH      F      BLK       NONHISP  $35,000 - $49,999
# 37      billK  753    NH      F      WHT       NONHISP  $80,000 - $94,999
# 38      billK  754    NH      M      WHT       NONHISP   $95,000 and over
# 39      billK  759    NH      F      WHT       NONHISP            Unknown
# 40      billK  764    NH      F      BLK       NONHISP  $35,000 - $49,999
# 41      billK  767    NH      M      BLK       NONHISP  $35,000 - $49,999
# 42      billK  781    CI      M      WHT       NONHISP  $80,000 - $94,999
# 43  bigCIfile  721    NH      M      WHT       NONHISP   $95,000 and over
# 44  bigCIfile  657    NH      M      WHT       NONHISP  $50,000 - $64,999
# 45  bigCIfile  666    NH      M      WHT       NONHISP   $95,000 and over
# 46  bigCIfile  671    NH      F      BLK       NONHISP  $35,000 - $49,999
# 47  bigCIfile  686    NH      M      BLK       NONHISP  $10,000 - $14,999
# 48  bigCIfile  691    NH      F      WHT       NONHISP   $95,000 and over
# 49  bigCIfile  693    NH      F      WHT       NONHISP   $95,000 and over
# 50  bigCIfile  697    NH      F      BLK          HISP  $15,000 - $24,999
# 51  bigCIfile  663    NH      F      WHT       NONHISP  $50,000 - $64,999
# 52  bigCIfile  678    NH      M      WHT       NONHISP  $80,000 - $94,999
# 53  bigCIfile  498    CI      M      WHT       NONHISP  $80,000 - $94,999
# 54  bigCIfile  539    CI      M      WHT       NONHISP  $15,000 - $24,999
# 55  bigCIfile  340    CI      F      WHT       NONHISP   $95,000 and over
# 56  bigCIfile  436    CI      F      WHT       NONHISP  $35,000 - $49,999
# 57  bigCIfile  401    CI      M      WHT       NONHISP   $95,000 and over
# 58  bigCIfile  315    CI      M      WHT       NONHISP  $80,000 - $94,999
# 59  bigCIfile  159    CI      M      WHT       NONHISP  $25,000 - $34,999
#
#                      Eti  MI  BestPTA                    CM  \
# 0             Meningitis NaN   118.43             Oral/Cued
# 1                Unknown NaN   113.33             Oral/Cued
# 2                Unknown NaN   115.07             Oral/Cued
# 3                Unknown NaN    96.67             Oral/Cued
# 4                Unknown NaN    85.00             Oral/Cued
# 5                Unknown NaN   118.43             Oral/Cued
# 6                Unknown NaN   115.00             Oral/Cued
# 7                Genetic NaN    88.33             Oral/Cued
# 8           Mondini form NaN   101.67             Oral/Cued
# 9                Unknown NaN   108.33             Oral/Cued
# 10               Unknown NaN   118.43             Oral/Cued
# 11               Unknown NaN    96.67             Oral/Cued
# 12                   LVA NaN    90.00             Oral/Cued
# 13               Unknown NaN   113.37             Oral/Cued
# 14               Unknown NaN    85.00             Oral/Cued
# 15           Ototoxicity NaN    85.00             Oral/Cued
# 16               Unknown NaN    95.00               Sign/TC
# 17               Genetic NaN   118.43             Oral/Cued
# 18               Unknown NaN    85.00             Oral/Cued
# 19               Genetic NaN    91.67             Oral/Cued
# 20            Meningitis NaN    96.67             Oral/Cued
# 21               Unknown NaN    95.00             Oral/Cued
# 22  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 23  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 24  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 25  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 26  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 27  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 28  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 29  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 30  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 31  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 32  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 33  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 34  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 35  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 36  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 37  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 38  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 39  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 40  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 41  N/A - Normal Hearing NaN  3333.00  N/A - Normal Hearing
# 42               Unknown NaN    85.00             Oral/Cued
# 43  N/A - Normal Hearing NaN   999.00  N/A - Normal Hearing
# 44  N/A - Normal Hearing NaN   999.00  N/A - Normal Hearing
# 45  N/A - Normal Hearing NaN   999.00  N/A - Normal Hearing
# 46  N/A - Normal Hearing NaN   999.00  N/A - Normal Hearing
# 40  N/A - Normal Hearing      3333  3333.00   11.03  3333.00
# 41  N/A - Normal Hearing      3333  3333.00   14.94  3333.00
# 42         Auditory Oral         0    27.24   10.06     7.79
# 43  N/A - Normal Hearing       999   999.00   10.48   999.00
# 44  N/A - Normal Hearing       999   999.00   17.54   999.00
# 45  N/A - Normal Hearing       999   999.00   12.07   999.00
# 46  N/A - Normal Hearing       999   999.00   12.65   999.00
# 47  N/A - Normal Hearing       999   999.00   12.02   999.00
# 48  N/A - Normal Hearing       999   999.00   15.78   999.00
# 49  N/A - Normal Hearing       999   999.00   15.83   999.00
# 50  N/A - Normal Hearing       999   999.00   16.70   999.00
# 51  N/A - Normal Hearing       999   999.00   25.30   999.00
# 52  N/A - Normal Hearing       999   999.00   23.99   999.00
# 53         Auditory Oral         0    22.11   10.72     8.87
# 54         Auditory Oral         0    17.12    9.86     8.43
# 55         Auditory Oral         0    11.07   11.55    10.63
# 56         Auditory Oral         0    12.19   11.44    10.43
# 57         Auditory Oral         0    43.47   17.39    13.76
# 58         Auditory Oral        24    67.94   18.03    12.37
# 59         Auditory Oral         0    68.63   25.56    19.84
#
#               TestDev  @4ppvtae  @4ppvtss
# 0            CI Right        59        54
# 1             CI Left        83        90
# 2           CI-BinSeq        57        42
# 3             CI Left        48        44
# 4             CI Left       107       114
# 5           CI-BinSeq        78        81
# 6            CI Right        79        52
# 7   CI Right, HA Left       111       106
# 8             CI Left        56        48
# 9             CI Left       110       109
# 10          CI-BinSeq        71        54
# 11          CI-BinSeq        97        81
# 12          CI-BinSeq       114       111
# 13          CI-BinSeq        75        75
# 14          CI-BinSeq        96       112
# 15          CI-BinSeq        84        87
# 16          CI-BinSeq        78        54
# 17          CI-BinSeq        73        54
# 18          CI-BinSeq        85        78
# 19            CI Left       101       115
# 20          CI-BinSeq       110       123
# 21          CI-BinSeq       110       104
# 22             No Aid        96       108
# 23             No Aid       121       108
# 24             No Aid       101       121
# 25             No Aid       111       121
# 26             No Aid       124       117
# 27             No Aid       120       115
# 28             No Aid       106       106
# 29             No Aid       109       114
# 30             No Aid       110       108
# 31             No Aid       123        99
# 32             No Aid       110       120
# 33             No Aid        96       102
# 34             No Aid       146       123
# 35             No Aid        85       102
# 36             No Aid        92        90
# 37             No Aid       117       111
# 38             No Aid       106       117
# 39             No Aid       114       100
# 40             No Aid       100       117
# 41             No Aid        83        99
# 42          CI-BinSeq       104        90
# 43             No Aid       183       127
# 44             No Aid       299       117
# 45             No Aid       299       132
# 46             No Aid       153       100
# 47             No Aid       100        79
# 48             No Aid       215       105
# 49             No Aid       215       105
# 50             No Aid       171        92
# 51             No Aid       299       103
# 52             No Aid       299       101
# 53          CI-BinSeq       110        90
# 54          CI-BinSeq        61        59
# 55          CI-BinSeq       143       102
# 56           CI Right       165       111
# 57           CI Right       123        74
# 58  CI Left, HA Right       263       104
# 59           CI Right       221        92

# %%
data_cochlear = pd.read_csv("Raw Data/data-cochlear.txt", delimiter= "\t")
words = data_cochlear["Word"].tolist()
data_cochlear
# Out:
#            ID    Word
# 0     CAF-657  lizard
# 1     CAF-657     cat
# 2     CAF-657    hawk
# 3     CAF-657     dog
# 4     CAF-657  turtle
# ...       ...     ...
# 1295  SZA-781   puppy
# 1296  SZA-781  kitten
# 1297  SZA-781   goose
# 1298  SZA-781    duck
# 1299  SZA-781    wolf
#
# [1300 rows x 2 columns]

# %% [markdown]
# ### How many participants in data-cochlear.txt have a group designation in latest_demo.csv

# %%
participants_findings = pd.DataFrame()


#Unique IDs in data-cochlear.txt
participants = sorted(list(set(data_cochlear["ID"].tolist())))
print(participants)

participants_findings["Original ID"] = participants


#Participants list with only numbers. 
modified_participants = []
for part in participants: 
    modified_participants += [int(part[4:])]
    
participants_findings["Modified ID"] = modified_participants
#getting the number of responses by the participant ID. 



#Getting the groups for data-cochlear

#iterating and checking the 
groups = []
for id in modified_participants: 
    target = id
    
    condition = latest_demo["ID"] == id 
    
    if condition.any():
        group = latest_demo.loc[condition, 'Group'].values[0]
        groups += [group] 
    else: 
        groups += ["no group"]
print(groups)
partcipants_dict = {participants[i]: groups[i] for i in range(len(participants))}
print(partcipants_dict.items())


participants_findings["Group"] = groups
participants_findings.to_csv("Findings/participants_findings.csv")
# Out:
# ['CAF-657', 'CAJ-663', 'CAM-666', 'CAN-667', 'CAP-671', 'CAQ-672', 'CAR-673', 'CAS-674', 'CAU-667', 'CAV-678', 'CAY-681', 'CBD-686', 'CBF-691', 'CBH-693', 'CBJ-697', 'CBL-698', 'CBM-702', 'CBP-707', 'CBS-711', 'CBW-715', 'CCB-720', 'CCC-721', 'CCD-722', 'CCF-724', 'CCH-726', 'CCL-730', 'CCX-744', 'CDG-753', 'CDH-754', 'CDM-759', 'CDR-764', 'CDU-767', 'SFZ-149', 'SGO-159', 'SIU-211', 'SIZ-390', 'SKE-234', 'SMK-401', 'SNI-300', 'SNR-308', 'SNT-310', 'SNV-312', 'SNY-315', 'SOA-317', 'SOE-320', 'SOQ-329', 'SOX-335', 'SPA-338', 'SPC-340', 'SPH-344', 'SPL-436', 'SPV-450', 'SPX-452', 'SRF-483', 'SRR-498', 'SSG-520', 'SSZ-539', 'SUG-544', 'SUT-556', 'SUV-558', 'SVA-563', 'SVH-570', 'SVY-587', 'SZA-781']
# ['NH', 'NH', 'NH', 'no group', 'NH', 'NH', 'NH', 'NH', 'no group', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'NH', 'no group', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'no group', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI', 'CI']
# dict_items([('CAF-657', 'NH'), ('CAJ-663', 'NH'), ('CAM-666', 'NH'), ('CAN-667', 'no group'), ('CAP-671', 'NH'), ('CAQ-672', 'NH'), ('CAR-673', 'NH'), ('CAS-674', 'NH'), ('CAU-667', 'no group'), ('CAV-678', 'NH'), ('CAY-681', 'NH'), ('CBD-686', 'NH'), ('CBF-691', 'NH'), ('CBH-693', 'NH'), ('CBJ-697', 'NH'), ('CBL-698', 'NH'), ('CBM-702', 'NH'), ('CBP-707', 'NH'), ('CBS-711', 'NH'), ('CBW-715', 'NH'), ('CCB-720', 'NH'), ('CCC-721', 'NH'), ('CCD-722', 'NH'), ('CCF-724', 'NH'), ('CCH-726', 'NH'), ('CCL-730', 'NH'), ('CCX-744', 'NH'), ('CDG-753', 'NH'), ('CDH-754', 'NH'), ('CDM-759', 'NH'), ('CDR-764', 'NH'), ('CDU-767', 'NH'), ('SFZ-149', 'no group'), ('SGO-159', 'CI'), ('SIU-211', 'CI'), ('SIZ-390', 'CI'), ('SKE-234', 'CI'), ('SMK-401', 'CI'), ('SNI-300', 'CI'), ('SNR-308', 'CI'), ('SNT-310', 'CI'), ('SNV-312', 'CI'), ('SNY-315', 'CI'), ('SOA-317', 'no group'), ('SOE-320', 'CI'), ('SOQ-329', 'CI'), ('SOX-335', 'CI'), ('SPA-338', 'CI'), ('SPC-340', 'CI'), ('SPH-344', 'CI'), ('SPL-436', 'CI'), ('SPV-450', 'CI'), ('SPX-452', 'CI'), ('SRF-483', 'CI'), ('SRR-498', 'CI'), ('SSG-520', 'CI'), ('SSZ-539', 'CI'), ('SUG-544', 'CI'), ('SUT-556', 'CI'), ('SUV-558', 'CI'), ('SVA-563', 'CI'), ('SVH-570', 'CI'), ('SVY-587', 'CI'), ('SZA-781', 'CI')])

# %% [markdown]
# ### regroup the participants into three groups: without_group, NH, CI

# %%
#Number of individuals without a group designation 

without_group = []
NH = []
CI = [] 
i = 0 
while i < len(participants):
    if groups[i] == "no group":
        without_group += [participants[i]]
    if groups[i] == "NH": 
        NH += [participants[i]]
    if groups[i] == "CI":
        CI += [participants[i]]
    i += 1 
    
print(without_group)
print(len(without_group))
print("--------------------")

print(NH)
print(len(NH))
print("-------------")

print(CI) 
print(len(CI))
# Out:
# ['CAN-667', 'CAU-667', 'SFZ-149', 'SOA-317']
# 4
# --------------------
# ['CAF-657', 'CAJ-663', 'CAM-666', 'CAP-671', 'CAQ-672', 'CAR-673', 'CAS-674', 'CAV-678', 'CAY-681', 'CBD-686', 'CBF-691', 'CBH-693', 'CBJ-697', 'CBL-698', 'CBM-702', 'CBP-707', 'CBS-711', 'CBW-715', 'CCB-720', 'CCC-721', 'CCD-722', 'CCF-724', 'CCH-726', 'CCL-730', 'CCX-744', 'CDG-753', 'CDH-754', 'CDM-759', 'CDR-764', 'CDU-767']
# 30
# -------------
# ['SGO-159', 'SIU-211', 'SIZ-390', 'SKE-234', 'SMK-401', 'SNI-300', 'SNR-308', 'SNT-310', 'SNV-312', 'SNY-315', 'SOE-320', 'SOQ-329', 'SOX-335', 'SPA-338', 'SPC-340', 'SPH-344', 'SPL-436', 'SPV-450', 'SPX-452', 'SRF-483', 'SRR-498', 'SSG-520', 'SSZ-539', 'SUG-544', 'SUT-556', 'SUV-558', 'SVA-563', 'SVH-570', 'SVY-587', 'SZA-781']
# 30

# %% [markdown]
# ### Separating the groups and creating 3 txt files for without_groups, NH, CI

# %%
with open("Raw Data/data-cochlear.txt", "r") as contents: 
    first = contents.readline()
    lines = contents.readlines()
    

without_groups_data =[]
NH_data = []
CI_data = []


for line in lines: 
    if line[0:7] in without_group: 
        without_groups_data += [line]
    elif line[0:7] in NH: 
        NH_data += [line] 
    elif line[0:7] in CI: 
        CI_data += [line]

with open("Participant Data/NO-ID-cochlear-data.txt", "w") as contents: 
    contents.write("ID\tWord\n")
    for item in without_groups_data: 
        contents.write(item)
        


with open("Participant Data/NH-cochlear-data.txt", "w") as f: 
    f.write("ID\tWord\n")
    for item in NH_data: 
I-300\tkiller\n', 'SNI-300\twhale\n', 'SNI-300\tshark\n', 'SNI-300\tseahorse\n', 'SNI-300\tpenguin\n', 'SNI-300\tgiraffe\n', 'SNI-300\telephant\n', 'SNI-300\talligator\n', 'SNI-300\tlizard\n', 'SNI-300\tbobcat\n', 'SNI-300\ttiger\n', 'SNI-300\tleopard\n', 'SNI-300\tjaguar\n', 'SNI-300\tdog\n', 'SNI-300\tcat\n', 'SNI-300\tparrot\n', 'SNI-300\thorse\n', 'SNR-308\tpanther\n', 'SNR-308\ttiger\n', 'SNR-308\tbobcat\n', 'SNR-308\tdog\n', 'SNR-308\tshepherd\n', 'SNR-308\tpigeon\n', 'SNR-308\tfalcon\n', 'SNR-308\teagle\n', 'SNR-308\tfox\n', 'SNR-308\twolf\n', 'SNR-308\tbear\n', 'SNR-308\tbuffalo\n', 'SNR-308\tkoala\n', 'SNR-308\tpolar\n', 'SNR-308\tpenguin\n', 'SNR-308\tkitten\n', 'SNT-310\tpenguin\n', 'SNT-310\telephant\n', 'SNT-310\tzebra\n', 'SNT-310\tflamingo\n', 'SNT-310\tfrog\n', 'SNT-310\tdog\n', 'SNT-310\tcat\n', 'SNT-310\tbird\n', 'SNT-310\tpigeon\n', 'SNT-310\tseagull\n', 'SNT-310\tpig\n', 'SNT-310\tcow\n', 'SNT-310\thorse\n', 'SNT-310\tarmadillo\n', 'SNT-310\tsquirrel\n', 'SNT-310\tmouse\n', 'SNT-310\tskunk\n', 'SNT-310\traccoon\n', 'SNT-310\tfox\n', 'SNT-310\tbear\n', 'SNT-310\tlion\n', 'SNT-310\ttiger\n', 'SNT-310\tpanther\n', 'SNT-310\tcougar\n', 'SNT-310\tmoose\n', 'SNT-310\tcaribou\n', 'SNT-310\tdeer\n', 'SNV-312\tcat\n', 'SNV-312\tdog\n', 'SNV-312\tfish\n', 'SNV-312\tturtle\n', 'SNV-312\tbird\n', 'SNV-312\talligat ...

# %% [markdown]
# ### Counting the number of words produced from NH and CI

# %%
NH_words = pd.read_csv("Participant Data/NH-cochlear-data.txt", delimiter="\t")
CI_words = pd.read_csv("Participant Data/CI-cochlear-data.txt", delimiter="\t")

# NH_words.describe()
# CI_words.describe()



NH_dict = {NH[i]: 0 for i in range(len(NH))}
CI_dict = {CI[i]: 0 for i in range(len(CI))}

for line in NH_data: 
    NH_dict[line[0:7]] += 1

for line in CI_data:
    CI_dict[line[0:7]] += 1 


word_findings = pd.DataFrame(list(zip(NH_dict.keys(), NH_dict.values(), CI_dict.keys(), CI_dict.values())), columns=['NH ID', 'NH Word Count', 'CI ID', 'CI Word Count'])

word_findings.to_csv("Findings/word_findings.csv")

# %% [markdown]
# ## Creating a Modified participant data with replacments (ex. chimp -> chimpanzee -> primate)

# %%
import pandas as pd 

NH = pd.read_csv("Participant Data/Original Data/NH-cochlear-data.txt",delimiter="\t")
# Out:
#   File "/var/folders/n_/3k9s85c56g37ggzrl97h_fch0000gn/T/ipykernel_43607/3029872791.py", line 3
#     NH = pd.read_csv("Participant Data/Original Data/NH-cochlear-data.txt",delimiter=")
#                                                                                        ^
# SyntaxError: EOL while scanning string literal
